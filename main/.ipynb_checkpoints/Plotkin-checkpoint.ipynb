# %%
import numpy as np
import matplotlib.pyplot as plt
import utils as ut

# %%
# this string must be passed during the execution of gillespie_test.exe
data_dir = '../data/plotkin/'

# %%
params = dict()

# LV parameters
params['betas'] = [1, 1.5]
params['alpha'] = 0.5
params['M'] = 100

# Gillespie parameters
params['end_cond'] = 'time'
params['max_steps'] = 20000
#params['end_cond'] = 'passage'
#params['up_bounds'] = [2000,2000]
#params['low_bounds'] = [0,0]
params['traj_step'] = 1
params['init_state'] = [params['M'], params['M']] # Initial condition
params['N_real'] = 1000

# %%
ut.write_params(params, data_dir, 'param.txt')

# %%
av_traj, labels = ut.read_traj(data_dir+'moment_1.00.txt')
m2_traj, labels = ut.read_traj(data_dir+'moment_2.00.txt')
av_ts = av_traj[:,0]
av_xs = av_traj[:,2]
av_Ns = av_traj[:,3]
m2_xs = m2_traj[:,2]
m2_Ns = m2_traj[:,3]

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(9,3.5))

ax1.set_xlabel('Time')
ax1.set_ylabel('N. individuals, $N$')
ax1.plot(av_ts, av_Ns, c='black', ls='--')
std = np.sqrt(m2_Ns - av_Ns**2)
ax1.fill_between(av_ts, av_Ns - std, av_Ns + std, alpha=0.6)


ax2.set_xlabel('Time')
ax2.set_ylabel('Fract of 1, $x$')
ax2.plot(av_ts, av_xs, c='black', ls='--')
std = np.sqrt(m2_xs - av_xs**2)
ax2.fill_between(av_ts, av_xs - std, av_xs + std, alpha=0.6)

plt.tight_layout()

# %%
def drift_coef(x, N, params):
    return x * (1-x) * (params['betas'][0] - params['betas'][1])

# %%
def integrate(dt, drift):
